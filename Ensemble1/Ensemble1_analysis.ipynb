# %%
### Import libar
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
os.getcwd()
# Out:
# 'c:\\Users\\konst\\Documents\\_Master_Thesis\\Code\\microCOSM_deep\\Ensemble1'

# %%
### Import dataset

data_ens1 = pd.read_csv('ensembleoutput.csv')

# %%
data_ens1.head()
# Out:
#     id  dt(s)     t(yr)  rFeC_pb           mu0       m_l  m_q  kappa  \
# 0  100   7200  0.000001  0.00004  1.157407e-07  0.000012    0      0
# 1  101   7200  0.000001  0.00004  1.157407e-07  0.000012    0      0
# 2  102   7200  0.000001  0.00004  1.157407e-07  0.000012    0      0
# 3  103   7200  0.000001  0.00004  1.157407e-07  0.000012    0      0
# 4  104   7200  0.000001  0.00004  1.157407e-07  0.000012    0      0
#
#       kfe_p   kldoc_p  ...  DIC(2)  DIC(3)  ALK(1)  ALK(2)  ALK(3)  OCPCO2(1)  \
# 0  0.000000  0.000102  ...     NaN     NaN     NaN     NaN     NaN        NaN
# 1  0.000000  0.000102  ...     NaN     NaN     NaN     NaN     NaN        NaN
# 2  0.000000  0.000102  ...     NaN     NaN     NaN     NaN     NaN        NaN
# 3  0.000001  0.000102  ...     NaN     NaN     NaN     NaN     NaN        NaN
# 4  0.000001  0.000102  ...     NaN     NaN     NaN     NaN     NaN        NaN
#
#    OCPCO2(2)  OCPCO2(3)  ATPCO2  Limit
# 0        NaN        NaN       0    444
# ...

# %%
### change the values in column of kldoc_p
### replace 0.00102 with 1E-7

data_ens1['kldoc_p'] = data_ens1['kldoc_p'].replace(0.000102, 1E-7)

# %%
data_ens1.head()
# Out:
#     id  dt(s)     t(yr)  rFeC_pb           mu0       m_l  m_q  kappa  \
# 0  100   7200  0.000001  0.00004  1.157407e-07  0.000012    0      0
# 1  101   7200  0.000001  0.00004  1.157407e-07  0.000012    0      0
# 2  102   7200  0.000001  0.00004  1.157407e-07  0.000012    0      0
# 3  103   7200  0.000001  0.00004  1.157407e-07  0.000012    0      0
# 4  104   7200  0.000001  0.00004  1.157407e-07  0.000012    0      0
#
#       kfe_p       kldoc_p  ...  DIC(2)  DIC(3)  ALK(1)  ALK(2)  ALK(3)  \
# 0  0.000000  1.000000e-07  ...     NaN     NaN     NaN     NaN     NaN
# 1  0.000000  1.000000e-07  ...     NaN     NaN     NaN     NaN     NaN
# 2  0.000000  1.000000e-07  ...     NaN     NaN     NaN     NaN     NaN
# 3  0.000001  1.000000e-07  ...     NaN     NaN     NaN     NaN     NaN
# 4  0.000001  1.000000e-07  ...     NaN     NaN     NaN     NaN     NaN
#
#    OCPCO2(1)  OCPCO2(2)  OCPCO2(3)  ATPCO2  Limit
# 0        NaN        NaN        NaN       0    444
# ...

# %%
### give me all the unique values in column of kldoc_p

data_ens1['kldoc_p'].unique()
# Out:
# array([1.e-07])
